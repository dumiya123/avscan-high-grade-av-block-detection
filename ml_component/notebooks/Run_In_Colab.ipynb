# %% [markdown]
# # AtrionNet: Complete Model Training Pipeline
#
# This notebook automates the training of the AtrionNet Hybrid model.
# It mounts your Google Drive, installs dependencies, downloads the LUDB dataset, and starts the training loop.
#
# ### Prerequisites:
# 1. Upload the `AtrionNet_Implementation.zip` file to the root of your Google Drive.
# 2. Ensure Runtime Type is set to **T4 GPU**.

# %%
# 1. Setup Environment
from google.colab import drive
import torch
import os

drive.mount('/content/drive')

if torch.cuda.is_available():
    print(f"\n✅ GPU Accelerated: {torch.cuda.get_device_name(0)}")
else:
    print("\n❌ ERROR: GPU not detected. Go to Runtime -> Change Runtime Type and select T4 GPU.")

# %%
# 2. Deploy Project Content
# Note: Change the zip filename if it is different in your Drive
ZIP_PATH = '/content/drive/MyDrive/AtrionNet_Implementation.zip'

if os.path.exists(ZIP_PATH):
    # !unzip -o {ZIP_PATH} -d /content/
    # %cd /content/AtrionNet_Implementation/ml_component
    # !pip install -r requirements.txt
else:
    print(f"❌ ERROR: Could not find {ZIP_PATH} in your Drive.")

# %%
# 3. Fetch Data & Start Training
# This cell downloads the LUDB dataset and directly starts the training script.
# !python download_data.py
# !python train.py
