# %% [markdown]
# # ECG Data Download and Preprocessing
#
# This notebook demonstrates data download and preprocessing.

# %%
import sys
sys.path.insert(0, '../')

from src.data.download import download_ludb
from src.data.preprocessing import preprocess_datasets

# %% [markdown]
# ## 1. Download Datasets

# %%
# Download LUDB
download_ludb(output_dir='../data/raw')

# %% [markdown]
# ## 2. Preprocess Data

# %%
# Process all datasets
preprocess_datasets(
    raw_dir='../data/raw',
    output_dir='../data/processed',
    validate=True
)
