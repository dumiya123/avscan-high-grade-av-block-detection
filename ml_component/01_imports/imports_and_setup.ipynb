# %% [markdown]
# # Notebook 1: Imports and Environment Setup
#
# **Purpose:** This notebook sets up the Python environment for the entire AtrionNet research pipeline.
# It installs all required libraries and configures the project path so every other notebook can import
# from the `src/` folder without any issues.
#
# **Run this notebook first before running any other notebook.**

# %% [markdown]
# ## Step 1: Install Required Libraries
#
# These are the core packages needed for data loading, deep learning, and visualization.

# %%
# Install all required packages
# wfdb: reads PhysioNet ECG record files (.hea, .dat)
# tqdm: progress bars for training loops
# seaborn: improved matplotlib styling for publication plots
# !pip install -q wfdb tqdm matplotlib seaborn scikit-learn

# %% [markdown]
# ## Step 2: Configure Project Path
#
# We tell Python where to find our `src/` modules so all notebooks can use them.

# %%
import sys
import os
from pathlib import Path

# Resolve the ml_component root (one level up from this notebook folder)
PROJECT_ROOT = str(Path(os.getcwd()).parent)
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

print(f"Project root set to: {PROJECT_ROOT}")

# %% [markdown]
# ## Step 3: Import All Core Libraries
#
# This cell imports everything needed across the full pipeline.

# %%
# Standard libraries
import numpy as np
import random
import json

# Deep Learning
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader

# ECG Data
import wfdb

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Metrics
from scipy.signal import find_peaks
from tqdm import tqdm

print("All libraries imported successfully.")

# %% [markdown]
# ## Step 4: Check GPU Availability
#
# The model trains significantly faster on a GPU. This cell confirms if CUDA is available.

# %%
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device in use: {DEVICE}")

if DEVICE.type == 'cuda':
    print(f"GPU: {torch.cuda.get_device_name(0)}")
else:
    print("Warning: No GPU found. Training will be slow on CPU.")

# %% [markdown]
# ## Step 5: Set Global Seed for Reproducibility
#
# Fixing the random seed ensures that every run of this pipeline produces the same results.
# This is a requirement for any publishable research paper.

# %%
SEED = 42

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

print(f"Global seed set to: {SEED}")

# %% [markdown]
# ## Step 6: Create Output Directories
#
# These folders will hold trained model weights, plots, and evaluation reports.

# %%
os.makedirs(os.path.join(PROJECT_ROOT, 'weights'), exist_ok=True)
os.makedirs(os.path.join(PROJECT_ROOT, 'reports', 'plots'), exist_ok=True)
os.makedirs(os.path.join(PROJECT_ROOT, 'data', 'processed'), exist_ok=True)

print("Output directories are ready.")

# %% [markdown]
# ---
# **Setup complete. You can now proceed to `02_preprocessing/data_preprocessing.ipynb`.**
